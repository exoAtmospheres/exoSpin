# %%
from obliquity import *
from exoplanet_class import *
from plot_class import *

# %% [markdown]
# There is the demo of exoSpin package

# %%
## Data
#../../exoplanet/data/rp_vrot.txt
#6

# %%
x = obliquity()
# Out:
# Initializing ExoSpin ...
#
# -> ExoSpin Configuration
# -> ExoSpin Computing
#
# Easy method computing ...
#
# -> ExoSpin Plot
#
# There is the plot of AB Pic b's obliquity

# %%
orbital_plot = x.hist('Orbital inclination','red').plot()

# %%
radius_plot = x.pdf('Radius','orange').plot()
# Out:
# /home/idrissabd/Documents/Internship/exoSpin/exoSpin/plot_class.py:74: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
