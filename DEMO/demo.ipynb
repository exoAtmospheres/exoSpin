# %% [markdown]
# ### How to compute obliquity

# %%
from obliquity import *
from exoplanet_class import *
from plot_class import *

# %% [markdown]
# You need to charge your data from an .ini file

# %%
## Data
#../../exoplanet/data/rp_vrot.txt

# %% [markdown]
# Calling the function obliquity() will create an exoplanet class and it will also plot the exoplanet's obliquity
# Make sure to choose between the easy or the complex method of computing

# %% [markdown]
# ### Easy method

# %%
x = obliquity()
# Out:
# Initializing ExoSpin ...
#
# -> ExoSpin Configuration
#
# -> ExoSpin Computing
#
# Easy method computing ...
#
# -> ExoSpin Plot
#
# Plot - Obliquity of AB Pic b

# %% [markdown]
# ### Complex method

# %%
y = obliquity()
# Out:
# Initializing ExoSpin ...
#
# -> ExoSpin Configuration
#
# -> ExoSpin Computing
#
# Complex method computing ...
#
# -> ExoSpin Plot
#
# Plot - Obliquity of AB Pic b

# %%
a = x.hist('Orbital inclination','red')
b = x.pdf('Orbital inclination','red')

# %%
plt.figure()
y, x, _ = plt.hist(a.x, bins=200,color='red',alpha=0.3,density=True,label='$i_o$')
plt.title(a.title)
plt.xlabel(a.xlabel)
plt.plot(b.x,b.y, color='red',label='$i_o$ PDF ')
plt.legend()
plt.show()

# %%
x.hist('Orbital inclination','red').plot()
x.pdf('Radius','purple').plot()
